# %% [markdown]
# <h1><center> D-Wave Quantum Analysis </center></h1>

# %% [markdown]
# <h3> D-Wave Quantum is a industry leader in the development of quantum computing technology. Over time this investment has grown exponentially. The goal of this analysis is to determine the investment opportunities with this firm. I will analyze the history of the firm, its growth, loss record and it's viability for a potential investment strategy. I will implement a blend of technical and fundamental analysis. In addition I will build an algorithmic trading strategy for the investment.

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import os
import yfinance as yf

# %%
df = yf.download("QBTS", start = "2020-1-1", end = "2026-4-30", interval = '1d')

if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

df.columns.name = None
df.index.name = "Date"

df.to_csv('qbts.csv')

qbts = pd.read_csv('qbts.csv', 
                    index_col = "Date", 
                    parse_dates = True, 
                    date_format = '%Y-%m-%d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
qbts.index = df.index.strftime('%Y/%m/%d')

# %%
qbts.index = pd.to_datetime(qbts.index, format = '%Y/%m/%d')

# %%
print(qbts.index.dtype)
# Out:
# datetime64[us]

# %%
qbts.head()
# Out:
#             Close   High    Low   Open  Volume
# Date
# 2020-12-11  10.15  10.90  10.00  10.25  119400
# 2020-12-14  10.16  10.59  10.15  10.59  368700
# 2020-12-15  10.11  10.30  10.07  10.25  193700
# 2020-12-16  10.14  10.25  10.10  10.16  354900
# 2020-12-17  10.20  10.28  10.16  10.16  115500
